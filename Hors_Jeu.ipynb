# %% [markdown]
# <a href="https://colab.research.google.com/github/chachia-wacef/ComputerVision/blob/main/Hors_Jeu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
frame = cv2.imread('/content/4.jpg')
# affichage de l'image
cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x7F7D142C8C50>

# %%
# passage en noir et blanc, également pour accélerer 
# la détection
frame1 = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
cv2_imshow(frame1)
# application d'un seuil. Tous les pixels avec un niveau 
# supérieur à 80 sont montrés en blanc, et les autres en noir:
ret,frame1 = cv2.threshold(frame1,50,255,cv2.THRESH_BINARY)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F7D14265438>

# %%
# initialisation du HOG:
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# réduction de l'image pour une détection plus rapide
#frame = cv2.resize(frame, (640, 480))
#frame1 = cv2.resize(frame1, (640, 480)) 

frame = cv2.resize(frame,(1050, 1610))
frame1 = cv2.resize(frame1, (1050, 1610))

# détection des personnes dans l'image. 
# retourne les coordonnées de la boîte encadrant 
# les personnes détectées
#bounding_box_cordinates, weights =  HOGCV.detectMultiScale(frame, winStride = (4, 4), padding = (8, 8), scale = 1.03)
boxes, weights = hog.detectMultiScale(frame, winStride = (4, 4), padding = (8, 8), scale = 1.03)

boxes = np.array([[x, y, x + w, y + h] for (x, y, w, h) in boxes])

for (xA, yA, xB, yB) in boxes:
  # affichages des boîtes sur l'image couleur
  cv2.rectangle(frame, (xA, yA), (xB, yB),(0, 255, 0), 2)
  print('un autre')

# affichage de l'image résultante
cv2_imshow(frame)
# Out:
# un autre
# un autre
# un autre
# un autre
# un autre
# un autre
# un autre
# <PIL.Image.Image image mode=RGB size=1050x1610 at 0x7F7D14227A58>

# %%
#Pas bien

# %%
#quand on défénit la taille de l'image de (640,480) a (1050, 1610) 7 joueurs sont détectées contre 2 pour le premier size

# %%
#on va utiliser la méme photo mais en faite des modif sur lui (on découpe les parties de l'image unitile)

# %%
frame2 = cv2.imread('/content/44.jpg')
# affichage de l'image
cv2_imshow(frame2)
# Out:
# <PIL.Image.Image image mode=RGB size=847x675 at 0x7F7D142657F0>

# %%
# passage en noir et blanc, également pour accélerer 
# la détection
frame12 = cv2.cvtColor(frame2, cv2.COLOR_RGB2GRAY)
cv2_imshow(frame12)
# application d'un seuil. Tous les pixels avec un niveau 
# supérieur à 80 sont montrés en blanc, et les autres en noir:
ret,frame12 = cv2.threshold(frame12,50,255,cv2.THRESH_BINARY)
# Out:
# <PIL.Image.Image image mode=L size=847x675 at 0x7F7D14265BA8>

# %%
# initialisation du HOG:
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# réduction de l'image pour une détection plus rapide
#frame2 = cv2.resize(frame2, (640, 480))
#frame12 = cv2.resize(frame12, (640, 480)) 

frame2 = cv2.resize(frame2,(1050, 1610))
frame12 = cv2.resize(frame12, (1050, 1610))

# détection des personnes dans l'image. 
# retourne les coordonnées de la boîte encadrant 
# les personnes détectées
#bounding_box_cordinates, weights =  HOGCV.detectMultiScale(frame, winStride = (4, 4), padding = (8, 8), scale = 1.03)
boxes, weights = hog.detectMultiScale(frame2, winStride = (4, 4), padding = (8, 8), scale = 1.03)

boxes = np.array([[x, y, x + w, y + h] for (x, y, w, h) in boxes])

for (xA, yA, xB, yB) in boxes:
  # affichages des boîtes sur l'image couleur
  cv2.rectangle(frame2, (xA, yA), (xB, yB),(0, 255, 0), 2)
  print('un autre')

# affichage de l'image résultante
cv2_imshow(frame2)
# Out:
# un autre
# un autre
# un autre
# un autre
# un autre
# un autre
# un autre
# un autre
# un autre
# un autre
# un autre
# <PIL.Image.Image image mode=RGB size=1050x1610 at 0x7F7D143074E0>

# %%
#le résultat est plus beau que le premier

# %%
#il nous faut :
#changer quelques paramétres du détecteur
#traiter plus l'image
#changer quelques valeurs de threshold , padding , scale .......
